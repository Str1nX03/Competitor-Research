# %%
from src.utils import get_llm

text = "What is python?"

llm = get_llm()

response = llm.invoke(text)

# %%
print(response.content)
# Out:
# Python is a high‑level, interpreted programming language known for its readability, simplicity, and versatility. It was created by Guido van Rossum and first released in 1991. Python emphasizes clear, concise syntax (often called “executable pseudocode”) and supports multiple programming paradigms, including procedural, object‑oriented, and functional styles.
#
# Key features:
#
# - **Easy to learn and use** – its syntax is designed to be intuitive, making it popular for beginners and experienced developers alike.
# - **Dynamic typing** – variables don’t need explicit type declarations.
# - **Extensive standard library** – “batteries‑included” modules for file I/O, networking, web services, data manipulation, and more.
# - **Cross‑platform** – runs on Windows, macOS, Linux, and many other operating systems.
# ...

# %%
from src.utils import web_search

question = "What is AGI?"

response = web_search(question)

# %%
response
# Out:
# ['Not to be confused with Generative artificial intelligence or Artificial superintelligence. **Artificial general intelligence** (**AGI**) is a hypothetical type of artificial intelligence that matches or surpasses human capabilities across virtually all cognitive tasks. Some AI experts and industry figures have stated that mitigating the risk of human extinction posed by AGI should be a global priority. AGI is also known as strong AI, full AI, human-level AI, human-level intelligent AI, or general intelligent action. An artificial superintelligence (ASI) is a hypothetical type of AGI that is much more generally intelligent than humans, while the notion of transformative AI relates to AI having a large impact on society, for example, similar to the agricultural or industrial revolution. For example, a competent AGI is defined as an AI that outperforms 50% of skilled adults in a wide range of non-physical tasks, and a superhuman AGI (i.e., an artificial superintelligence) is similarl
# ...

# %%
INTENT_DETECTION_PROMPT = """

You are a assistant whose task is to see the user query:-

{user_input}

And then decide whether the given query is about:-

1. Idea of a Product/Project/SaaS proposed by the user:- return "idea"
2. Company Description/Profile provided by the user:- return "company"
3. Product/Project/SaaS Description provided by the user:- return "product"

Return only one word only.

"""

from src.utils import get_llm
from langchain_core.prompts import ChatPromptTemplate

llm = get_llm()
prompt = ChatPromptTemplate.from_template(INTENT_DETECTION_PROMPT)
user_input = "There is an agency as Lyzr.ai which makes Agentic Systems for their client."
response = llm.invoke(prompt.format(
    user_input = user_input
))

# %%
response.content
# Out:
# 'company'

# %%
CONTEXT_RETRIEVAL_PROMPT = """

You are an assistant whose task is to ask 3 questions which you should search on internet to get the proper information about:-

User Input:- {user_input}
For the intent to get information on:- {user_intent} provided

If its an "idea", then ask questions to get most information to validate the idea and look for similar products description for more information.
If its a "company", then ask questions to get most information on similar working pattern and also how such companies work.
If its a "product", then ask questions to get most information about the product and also how it works.

Return only 3 questions in a list format.

Example:- ["question1", "question2", "question3"]

"""

from src.utils import get_llm, web_search
from langchain_core.prompts import ChatPromptTemplate
import json

llm = get_llm()
prompt = ChatPromptTemplate.from_template(CONTEXT_RETRIEVAL_PROMPT)
user_intent = "company"
user_input = "There is an agency as Lyzr.ai which makes Agentic Systems for their client."
response = llm.invoke(prompt.format(
    user_input = user_input,
    user_intent = user_intent
))

# %%
questions = json.loads(response.content)

# %%
context = []
for question in questions:

    results = web_search(question)

    for ans in results:

        context.append(ans)

# %%
context
# Out:
# ['## Lyzr AI. Lyzr AI is a New York-based enterprise software company founded in April 2023 by Siva Surendira, who also serves as CEO. The company builds a sovereign, full-stack platform for deploying and governing AI agents, allowing enterprises to run agentic systems locally within their own cloud or on-premise infrastructure without exposing proprietary data to foundation model providers. The company closed June 2026 at $12 million in annualized recurring revenue, up from $3.5 million in February 2026 and $650,000 at the end of Q3 2025, representing growth of approximately 200 percent quarter over quarter in Q2 2026 and 300 percent in the prior quarter. Lyzr operates at a 95 percent gross margin and reported it was approximately 30 days from breakeven as of July 2026. A newly launched hardware product, Lyzr Optimus, targets the on-premise AI inference market and is available for pre-order, with configurations ranging from $10,000 to $1 million.',
# ...

# %%
from src.agents.assistant_agent import AssistantAgent

assistant = AssistantAgent()

user_input = "I am thinking of building a Vibe Coding tool."

response = assistant.run(user_input = user_input)

# %%
response
# Out:
# ['The Best Vibe Coding Tools in 2026\nGreg Isenberg\n669000 subscribers\n2123 likes\n87998 views\n3 Nov 2025\nMicky and I rank the top vibe coding apps in 2025, from Cursor and Claude Code to Lovable, V0, Bolt, Windsurf, and emerging mobile-focused platforms. They break down which tools work best for technical developers versus non-technical builders, discuss the trust and ecosystem factors that matter when choosing a platform, and share hard-won lessons about the mindset shift required to build software with AI assistance.\n\nTimestamps\n00:00 – Intro\n01:11 – Windsurf\n03:46 – Cursor\n06:33 – Lovable, v0, Bolt\n10:17 – Mobile vibe coding: Rork, VibeCode App, Anything\n15:04 – Codex\n16:52 – Claude Code\n18:28 – Replit\n20:23 – Chef by Convex\n21:39 – Advice for Vibe Coders\n\nKey Points\n\n* Community size and tutorial availability matter as much as technical capability when choosing a vibe coding platform\n* For technical developers, Cursor and Claude Code dominate; for non-techni
# ...

# %%
COMPETITOR_EXTRACT_PROMPT = """
You are a strict data extraction agent. 
Your ONLY job is to extract competitor names from the context and return them as a JSON list.
Do NOT add explanations, do NOT add pricing, do NOT add founders.
If the company's product is the competitor, then extract the product name.
Example:- Anthropic's Claude for LLMs. Then Claude must be extracted.

Context:
{context}

Return STRICTLY as a JSON list. Example:
[
    "Competitor 1",
    "Competitor 2",
    .,
    .,
]
If none found, return []
"""
from src.utils import get_llm, web_search
from langchain_core.prompts import ChatPromptTemplate
import json

llm = get_llm()

context = ['## Lyzr AI. Lyzr AI is a New York-based enterprise software company founded in April 2023 by Siva Surendira, who also serves as CEO. The company builds a sovereign, full-stack platform for deploying and governing AI agents, allowing enterprises to run agentic systems locally within their own cloud or on-premise infrastructure without exposing proprietary data to foundation model providers. The company closed June 2026 at $12 million in annualized recurring revenue, up from $3.5 million in February 2026 and $650,000 at the end of Q3 2025, representing growth of approximately 200 percent quarter over quarter in Q2 2026 and 300 percent in the prior quarter. Lyzr operates at a 95 percent gross margin and reported it was approximately 30 days from breakeven as of July 2026. A newly launched hardware product, Lyzr Optimus, targets the on-premise AI inference market and is available for pre-order, with configurations ranging from $10,000 to $1 million.',
 'Lyzr is a full-stack agent framework that specializes in building fully autonomous AI agents for enterprises. Customer reception of Lyzr\'s LlamaIndex-powered agents has been overwhelmingly positive:. Customer Persona**: Lyzr’s ‘fully autonomous’ AI agents seem to have captured customer’s imagination with SaaS CTOs being the primary adopter of Lyzr AI Agents to automate their backend workflows in a more reliable, secure and predictable manner. > "SurePeople is delighted to announce our partnership with Lyzr.ai, a key player in fortifying the scalability, security, and future-readiness of our AI infrastructure. Lyzr has ambitious plans for the future, building on their success with LlamaIndex, including new agents such as Kathy, an AI competitor analyst, and Diane, an AI HR agent, with several others in the pipeline. By continuing to use LlamaIndex as their RAG partner, Lyzr is well-positioned to expand its offerings and further establish itself as a leader in autonomous AI agent technology for enterprises.',
 'Customer Support AI Cross Channel Support Email Triage Agent AI Phone Support Support Interaction CRM Case Generator Procurement Supplier Onboarding Supplier Sourcing Supplier Performance Contract Reviews Contract Search Agent Human Resources AI L&D ESAT Survey AI Performance Review Employee Onboarding AI Hiring Assistant Sales AI SDR AI Deal Nurturer Lead Enrichment ABM Agent AI Internal Communication Marketing AI Social Media Agent AEO/GEO Optimizer Agent AI Internal Communication Agent ABM Agent AI Content Creation Agent Banking KYC Processing AI loan Origination AI Loan Servicing Regulatory Monitoring Customer Onboarding Insurance Regulatory Compliance Claims Processing Policy Underwriting Partner Quality Assurance Litigation Clause Extraction. Agents to Production Banking Dispute Management The Field Guide for Analysts AI Sales Agents Use Cases Insurance AI Agents Use Cases Architect Agent Use cases. # The *State of AI Agents* in Enterprise: Q1 2026. This report reveals how real enterprises are designing, deploying, and scaling AI Agents today. state of ai agents-lyzr ai.',
 'Customer Support AI Cross Channel Support Email Triage Agent AI Phone Support Support Interaction CRM Case Generator Procurement Supplier Onboarding Supplier Sourcing Supplier Performance Contract Reviews Contract Search Agent Human Resources AI L&D ESAT Survey AI Performance Review Employee Onboarding AI Hiring Assistant Sales AI SDR AI Deal Nurturer Lead Enrichment ABM Agent AI Internal Communication Marketing AI Social Media Agent AEO/GEO Optimizer Agent AI Internal Communication Agent ABM Agent AI Content Creation Agent Banking KYC Processing AI loan Origination AI Loan Servicing Regulatory Monitoring Customer Onboarding Insurance Regulatory Compliance Claims Processing Policy Underwriting Partner Quality Assurance Litigation Clause Extraction. Agents to Production Banking Dispute Management The Field Guide for Analysts AI Sales Agents Use Cases Insurance AI Agents Use Cases Architect Agent Use cases. Agent Studio Talk to Us. How to Build Your Agentic AI Roadmap in 2026 | Architect by Lyzr. # How to Build Your *Agentic AI Roadmap* in 2026. You have not built an agent before and need to understand what you’re building before you commit to building it.',
 '* [Report this post](/uas/login?session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post_ellipsis-menu-semaphore-sign-in-redirect&guestReportContentType=POST&_f=guest-reporting). [27](https://www.linkedin.com/signup/cold-join?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post_social-actions-reactions)   [3 Comments](https://www.linkedin.com/signup/cold-join?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post_social-actions-comments). [Like](https://www.linkedin.com/signup/cold-join?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post_like-cta)   [Comment](https://www.linkedin.com/signup/cold-join?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post_comment-cta). * [Report this comment](/uas/login?session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post
://www.linkedin.com/signup/cold-join?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fkrishna-reddy-780a7286_the-4-agent-frameworks-that-will-define-ai-activity-7399658658479050752-klhL&trk=public_post_contextual-sign-in-modal_join-link).',
 '### Exclusive: Startup Lyzr.ai launches app builder aimed at moving agents to production in volume. Lyzr Inc., a startup that builds tools for deploying artificial intelligence agents in enterprises, will launch a new agentic application builder next week that it says lets nontechnical users create multi-agent systems to automate complex business processes. The product, called Architect, is positioned as an alternative to platforms such as Microsoft Corp.’s Copilot and Salesforce Inc.’s Agentforce, which Lyzr says often struggle to move beyond early prototypes and into production. “We are an agent infrastructure platform focused on production,” said Lyzr co-founder and Chief Executive Officer Siva Surendira. Surendira said Lyzr’s focus is on building and orchestrating production-grade agents, with tools for governance, evaluation, and simulation. The company has coined the term “organizational general intelligence” to describe its vision of a central intelligence layer that is continuously enriched by agents running in production. “With Lyzr, you get access to multiple models, and users can also call agents that are deployed centrally for the organization,” he said.']

comp = context[4:]

prompt = ChatPromptTemplate.from_template(COMPETITOR_EXTRACT_PROMPT)

response = llm.invoke(prompt.format(
                context = context
            ))

competitors = json.loads(response.content)

# %%
competitors
# Out:
# ['Microsoft Copilot', 'Salesforce Agentforce']

# %%
from src.agents.assistant_agent import AssistantAgent
from src.agents.researcher_agent import ResearcherAgent
from src.agents.reporter_agent import ReporterAgent

assistant = AssistantAgent()
researcher = ResearcherAgent()
reporter = ReporterAgent()

user_input = "I am thinking of building a Vibe Coding tool."

context = assistant.run(user_input = user_input)
research_data = researcher.run(context = context)
report = reporter.run(research_data = research_data)

# %%
context
# Out:
# ['# What is vibe coding? “Vibe coding” is a new and loosely defined term in software development that refers to the practice of prompting AI tools to generate code rather than writing code manually. In software engineering, development is reshaping from strict, manual coding and becoming more flexible, AI-assisted and AI-powered through generative AI and AI-assisted coding. Vibe coding is at the forefront of this change. “Vibe coding” represents a shift toward intent-driven software development, where AI systems assist developers by generating code from natural language instructions. According to Andrej Karpathy, it’s a coding strategy that involves minimal human coding because programmers and coders use AI codes in their programming tasks but concentrate more on how the result comes out, testing and fine-tuning. He also emphasized the significance of AI tools, coding tools and AI coding assistants in software development. The field of vibe coding has moved from basic prompts for cod
# ...

# %%
research_data
# Out:
# {'Claude': [['I wanna see what some of your Claude websites look like. Can you post links of the sites you’ve made with Claude?'],
# ...

# %%
report
# Out:
# ['**Claude – Anthropic’s AI Assistant & Developer Platform**\n\n| Item | Details |\n|------|---------|\n| **Name** | Claude (Anthropic) |\n| **What they do** | Claude is a generative AI assistant built on Anthropic’s “constitutional AI” framework. It powers conversational chat, summarization, search, creative writing, Q&A, coding, and more. Anthropic offers Claude as a consumer‑facing chatbot, a developer API, and specialized tools (Claude Code, Claude Desktop, Claude Enterprise). |\n| **USP & What makes them unique** | • **Constitutional AI** – a safety‑first training paradigm that explicitly encodes helpfulness, honesty, and harmlessness. <br>• **Multi‑product ecosystem** – distinct offerings (Chat, Code, Desktop, API, Enterprise) allow users to pick the right tool for the job. <br>• **Enterprise‑grade developer tools** – Claude Code provides agentic coding in IDEs, terminals, and the web; Claude Enterprise adds governance, compliance, and dedicated support. |\n| **Market captured 
# ...
