# %%
from src.agents.researcher_agent import ResearcherAgent

query = "I am thinking of building an AI Customer Support System."

researcher = ResearcherAgent()

researched_data = researcher.run(user_input = query)

# %%
researched_data
# Out:
# {'user_input': 'I am thinking of building an AI Customer Support System.',
#  'competitors': ['{"competitors":["Lorikeet"',
#   '"Fin by Intercom"',
#   '"Sierra"',
#   '"Decagon"',
#   '"Salesforce Agentforce"',
#   '"Zendesk AI"',
#   '"Ada"',
#   '"Forethought"',
#   '"Gorgias"',
#   '"Kore.ai"]}'],
# ...

# %%
competitors = "Claude, ChatGPT"
competitors = competitors.split(",")

# %%
competitors
# Out:
# ['Claude', ' ChatGPT']

# %%
from src.utils import web_search

query = "who are the competitors of google?"
response = web_search(query)

# %%
response
# Out:
# ["# Google's Main Competitors: Microsoft, Netflix, and More. * Google dominates the global search engine market with almost 90% of online search volume as of March 2026. * Alphabet, Google's parent company, includes other subsidiaries like Verily and Calico, and owns Fitbit, Nest, and YouTube under Google. Google’s mission is to organize information and make it easily accessible.1 Operated under its parent company Alphabet, Google works in cloud computing, entertainment, and autonomous vehicles, but dominates the search engine market. It faces competitors in different sectors, including Microsoft and Bing in search, Netflix in streaming, and Tesla in self-driving technology. Google is nearly a monopoly in the online search arena, with more than 89.85% of the online search market and volume as of March 2026.2 This dominance leaves little room for competitors that are trying to outsmart and outperform the search engine that generates its revenue through ads.",
# ...
